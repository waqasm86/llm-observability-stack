# %%
from IPython.display import display, HTML

display(HTML("""
<style>
    /* Target the specific container for shell/terminal output */
    .jp-OutputArea-output pre {
        white-space: pre !important;
        overflow-x: auto !important;
        display: block !important;
        width: max-content;
        min-width: 100%;
    }
    /* Ensure the output area itself allows the scrollbar */
    .jp-OutputArea-child {
        overflow-x: auto !important;
    }
</style>
"""))

# %%
#MUST RUN THIS COMMAND IN LINUX TERMINAL
#!kubectl port-forward -n llm-observability svc/ollama 11434:11434

# %%
#Run this command in linux terminal only. 
#!kubectl exec -it -n llm-observability langchain-demo-5dc95b9dbf-8ttrx -- /bin/bash

# %%
#!helm upgrade --install llm-observability-stack . -n llm-observability -f values.local-k3s.yaml

# %%
# !kubectl describe pod langchain-demo-5dc95b9dbf-fz9gz -n llm-observability

# %%
# !kubectl logs langchain-demo-5dc95b9dbf-fz9gz -n llm-observability

# %%
# !kubectl rollout status deployment/langchain-demo -n llm-observability

# %%
# !kubectl get deployment langchain-demo -n llm-observability -o yaml | grep -A 10 readinessProbe

# %%
#Run this command in linux terminal
#!kubectl port-forward -n llm-observability svc/ollama 11434:11434

# %%
# !curl 127.0.0.1:11434/api/tags

# %%
# !curl -s http://127.0.0.1:11434/api/tags | jq '.'
